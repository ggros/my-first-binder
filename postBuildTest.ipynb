# %%
using DataFrames
using CSV
using Plots

# %%
data = CSV.read("gapminder.csv", DataFrame)
# Out:
# 2×13 DataFrame
#  Row │ country      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_ ⋯
#      │ String15     Float64         Float64         Float64         Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Australia           10039.6         10949.6         12217.2         145 ⋯
#    2 │ New Zealand         10556.6         12247.4         13175.7         144
#                                                                9 columns omitted

# %%
df = CSV.File("gapminder.csv") |> DataFrame
# Out:
# 2×13 DataFrame
#  Row │ country      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_ ⋯
#      │ String15     Float64         Float64         Float64         Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Australia           10039.6         10949.6         12217.2         145 ⋯
#    2 │ New Zealand         10556.6         12247.4         13175.7         144
#                                                                9 columns omitted

# %%
# Extract the row corresponding to Australia
aus_gdp = data[data[:, :country] .== "Australia", :]
aus_gdp = Matrix(aus_gdp[:,2:end])[:]  # as vector (remove first col, convert to Matrix and then keep 1 col)
# Out:
# 12-element Vector{Float64}:
#  10039.59564
#  10949.64959
#  12217.22686
#  14526.12465
#  16788.62948
#  18334.19751
#  19477.00928
#  21888.88903
#  23424.76683
#  26997.93657
#  30687.75473
#  34435.36744

# %%
# Extract the years as Ints from the column names
years = [x[end-3:end] for x in names(data)[2:end]]
years = parse.(Int, years)
# Out:
# 12-element Vector{Int64}:
#  1952
#  1957
#  1962
#  1967
#  1972
#  1977
#  1982
#  1987
#  1992
#  1997
#  2002
#  2007

# %%
# Plot
plot(years, aus_gdp)
